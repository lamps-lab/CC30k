# %%
"""
R001_Fall_2023_AI_Reproducibility__
|
R_001_MTurk_Sentiment_Analysis_5_models.ipynb
Created on Thu Jan 23 18:41:36 2025
@author: Rochana Obadage
"""

# %%
import torch

print(torch.cuda.is_available())
print(torch.cuda.device_count())
print(torch.cuda.current_device())
# Out:
# True
# 1
# 0

# %% [markdown]
# # Model 01
# ##### https://huggingface.co/j-hartmann/sentiment-roberta-large-english-3-classes
#
# ##### model="j-hartmann/sentiment-roberta-large-english-3-classes"
#
# #### M1_j_hartmann
#
# The model was fine-tuned on 5,304 manually annotated social media posts.
#
# @article{hartmann2021,
#   title={The Power of Brand Selfies},
#   author={Hartmann, Jochen and Heitmann, Mark and Schamp, Christina and Netzer, Oded},
#   journal={Journal of Marketing Research}
#   year={2021}
# }1}
# }1}
# }

# %%
from transformers import pipeline
# sentiment_pipeline = pipeline("text-classification", model="j-hartmann/sentiment-roberta-large-english-3-classes", return_all_scores=True)
# data = ["I love you", "I hate you","I am neutral"]
# print(sentiment_pipeline(data))
# sentiment_pipeline.save_pretrained("sentiment_analysis/saved_5_models/model_01/")
model_01_pipeline = pipeline("text-classification", model = "sentiment_analysis/saved_5_models/model_01/")

print(model_01_pipeline)
# Out:
# 2025-01-14 15:48:31.048958: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-14 15:48:39.689726: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %%
data = ["I love you", "I hate you","I am neutral"]
print(model_01_pipeline(data))
# Out:
# [{'label': 'positive', 'score': 0.9996191263198853}, {'label': 'negative', 'score': 0.9990231990814209}, {'label': 'neutral', 'score': 0.9977341890335083}]

# %%
print(sentiment_pipeline(data))
# Out:
# [[{'label': 'negative', 'score': 0.00018510829249862581}, {'label': 'neutral', 'score': 0.0001957259955815971}, {'label': 'positive', 'score': 0.9996191263198853}], [{'label': 'negative', 'score': 0.9990231990814209}, {'label': 'neutral', 'score': 0.0005650434759445488}, {'label': 'positive', 'score': 0.000411704444559291}], [{'label': 'negative', 'score': 0.0004821960174012929}, {'label': 'neutral', 'score': 0.9977341890335083}, {'label': 'positive', 'score': 0.0017836499027907848}]]

# %% [markdown]
# # Model 02
# ##### https://huggingface.co/Seethal/sentiment_analysis_generic_dataset
#
# ##### model="Seethal/sentiment_analysis_generic_dataset"
#
# #### M2_Seethal
# This is a fine-tuned downstream version of the bert-base-uncased model for sentiment analysis, this model is not intended for further downstream fine-tuning for any other tasks. This model is trained on a classified dataset for text classification. (GENERIC dataset)

# %%
from transformers import pipeline
# sentiment_pipeline = pipeline("text-classification", model="Seethal/sentiment_analysis_generic_dataset", return_all_scores=True)
# data = ["I love you", "I hate you","I am neutral"]
# print(sentiment_pipeline(data))
# sentiment_pipeline.save_pretrained("sentiment_analysis/saved_5_models/model_02/")
model_02_pipeline = pipeline("text-classification", model = "sentiment_analysis/saved_5_models/model_02/") #return_all_scores=True)

print(model_02_pipeline)

# %%
print(model_02_pipeline(data))

# LABEL_2 - positive
# LABEL_0 - negative
# LABEL_1 - neutral
# Out:
# [{'label': 'LABEL_2', 'score': 0.9963271021842957}, {'label': 'LABEL_0', 'score': 0.9952951073646545}, {'label': 'LABEL_1', 'score': 0.4930085241794586}]

# %% [markdown]
# # Model 03
# ##### https://huggingface.co/finiteautomata/bertweet-base-sentiment-analysis
#
# ##### model="finiteautomata/bertweet-base-sentiment-analysis"
#
# #### M3_finiteautomata
#
# Model trained with SemEval 2017 corpus (around ~40k tweets). Base model is BERTweet, a RoBERTa model trained on English tweets.Uses POS, NEG, NEU labels.
#
# @misc{perez2021pysentimiento,
#       title={pysentimiento: A Python Toolkit for Sentiment Analysis and SocialNLP tasks},
#       author={Juan Manuel Pérez and Juan Carlos Giudici and Franco Luque},
#       year={2021},
#       eprint={2106.09462},
#       archivePrefix={arXiv},
#       primaryClass={cs.CL}
# }s.

# %%
from transformers import pipeline
# sentiment_pipeline = pipeline("text-classification", model="finiteautomata/bertweet-base-sentiment-analysis", return_all_scores=True)
# data = ["I love you", "I hate you","I am neutral"]
# print(sentiment_pipeline(data))
# sentiment_pipeline.save_pretrained("sentiment_analysis/saved_5_models/model_03/")
model_03_pipeline = pipeline("text-classification", model = "sentiment_analysis/saved_5_models/model_03/")

print(model_03_pipeline)
# Out:
# emoji is not installed, thus not converting emoticons or emojis into text. Install emoji: pip3 install emoji==0.6.0
# ...

# %%
print(model_03_pipeline(data))
# Out:
# [{'label': 'POS', 'score': 0.9916695356369019}, {'label': 'NEG', 'score': 0.9806600213050842}, {'label': 'NEU', 'score': 0.9401856660842896}]

# %% [markdown]
# # Model 04
# ##### https://huggingface.co/Souvikcmsa/BERT_sentiment_analysis
#
# ##### model="Souvikcmsa/BERT_sentiment_analysis"
# #### M4_Souvikcmsa
# Model Trained Using AutoTrain
# Problem type: Multi-class Classification (3-class Sentiment Classification)

# %%
from transformers import pipeline
# sentiment_pipeline = pipeline("text-classification", model="Souvikcmsa/BERT_sentiment_analysis", return_all_scores=True)
# data = ["I love you", "I hate you","I am neutral"]
# print(sentiment_pipeline(data))
# sentiment_pipeline.save_pretrained("sentiment_analysis/saved_5_models/model_04/")
model_04_pipeline = pipeline("text-classification", model = "sentiment_analysis/saved_5_models/model_04/")

print(model_04_pipeline)

# %%
# print(model_01_pipeline(data))
# Out:
# [{'label': 'positive', 'score': 0.9996191263198853}, {'label': 'negative', 'score': 0.9990231990814209}, {'label': 'neutral', 'score': 0.9977341890335083}]

# %%
print(model_04_pipeline(data))
# Out:
# [{'label': 'positive', 'score': 0.9818135499954224}, {'label': 'negative', 'score': 0.9770167469978333}, {'label': 'neutral', 'score': 0.8292657732963562}]

# %% [markdown]
# # Model 05
# ##### https://huggingface.co/sbcBI/sentiment_analysis_model
#
# ##### model="sbcBI/sentiment_analysis_model"
#
# #### M5_sbcBI

# %%
from transformers import pipeline
# sentiment_pipeline = pipeline("text-classification", model="sbcBI/sentiment_analysis_model", return_all_scores=True)
# data = ["I love you", "I hate you","I am neutral"]
# print(sentiment_pipeline(data))
# sentiment_pipeline.save_pretrained("sentiment_analysis/saved_5_models/model_05/")
model_05_pipeline = pipeline("text-classification", model = "sentiment_analysis/saved_5_models/model_05/")

print(model_05_pipeline)

# %%
print(model_01_pipeline(data))
# Out:
# [{'label': 'positive', 'score': 0.9996191263198853}, {'label': 'negative', 'score': 0.9990231990814209}, {'label': 'neutral', 'score': 0.9977341890335083}]

# %%
print(model_05_pipeline(data))
# Out:
# [{'label': 'LABEL_2', 'score': 0.8693987727165222}, {'label': 'LABEL_0', 'score': 0.49276623129844666}, {'label': 'LABEL_2', 'score': 0.36295193433761597}]

# %%
print(model_02_pipeline(data))
# Out:
# [{'label': 'LABEL_2', 'score': 0.9963271021842957}, {'label': 'LABEL_0', 'score': 0.9952951073646545}, {'label': 'LABEL_1', 'score': 0.4930097460746765}]

# %%
# LABEL_2 --> positive
# LABEL_0 --> negative
# LABEL_1 --> neutral

# %% [markdown]
# # Load the datasets
# `label_file_list = [i for i in glob.glob("related_binary_labelled/*.csv")]`

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
from transformers import pipeline

import numpy as np
import pandas as pd
import os
import torch

import argparse
import sys
import glob
import os

# %%
df_test_1 = pd.read_csv(r"dataset/cc25k_dataset.csv")

df_test_filtered = df_test_1[['input_index','input_context','input_file_key','majority_vote','majority_agreement']].reset_index(drop=True)
df_test_filtered
# Out:
#        input_index                                      input_context  \
# 0                0  Instead of mixing the representations, G-Mixup...
# 1                3  For G-Mixup, we use the same hyper-parameters ...
# 2                6  G-Mixup performs mixup to the graphons of diff...
# 3                8  Our result generalizes that of [16] by allowin...
# 4                9  Note that for complexons of dimension 1, when ...
# ...            ...                                                ...
# 25824            2  A Jain [125] spatial associations + dynamic pr...
# 25825            3  A Jain [125] suggests training a deep network ...
# 25826            0  [39]12 2021 No name ICDAR PubTabNet ICDAR 2019...
# 25827            1  The source codes of 6 papers were not executab...
# 25828            3  [28] used biLSTM on table cell detection by en...
#
#              input_file_key majority_vote  majority_agreement
# 0       RS_001_MLRC_2022_01       Neutral                   3
# ...

# %% [markdown]
# # inferences model_01

# %%
df_test_filtered['input_context']
# Out:
# 0        Instead of mixing the representations, G-Mixup...
# 1        For G-Mixup, we use the same hyper-parameters ...
# 2        G-Mixup performs mixup to the graphons of diff...
# 3        Our result generalizes that of [16] by allowin...
# 4        Note that for complexons of dimension 1, when ...
#                                ...
# 25824    A Jain [125] spatial associations + dynamic pr...
# 25825    A Jain [125] suggests training a deep network ...
# 25826    [39]12 2021 No name ICDAR PubTabNet ICDAR 2019...
# 25827    The source codes of 6 papers were not executab...
# 25828    [28] used biLSTM on table cell detection by en...
# Name: input_context, Length: 25829, dtype: object

# %%
# inferences model_01
predictions_df = df_test_filtered.copy() #[["input_context"]]
x_test_series = predictions_df['input_context']

model_01_path = "sentiment_analysis/saved_5_models/model_01/"
loaded_model_01 = pipeline("text-classification", model = model_01_path, device=0)

predicted = loaded_model_01(list(x_test_series),truncation=True)
df_predicted = pd.DataFrame(predicted)

joined_new_df = predictions_df.reset_index().join(df_predicted, on='index', lsuffix='_')
joined_new_df = joined_new_df.rename(columns={"label": "m1_label", "score": "m1_score"})
joined_new_df = joined_new_df.drop(columns=['index'])
joined_new_df
# Out:
#        input_index                                      input_context  \
# 0                0  Instead of mixing the representations, G-Mixup...
# 1                3  For G-Mixup, we use the same hyper-parameters ...
# 2                6  G-Mixup performs mixup to the graphons of diff...
# 3                8  Our result generalizes that of [16] by allowin...
# 4                9  Note that for complexons of dimension 1, when ...
# ...            ...                                                ...
# 25824            2  A Jain [125] spatial associations + dynamic pr...
# 25825            3  A Jain [125] suggests training a deep network ...
# 25826            0  [39]12 2021 No name ICDAR PubTabNet ICDAR 2019...
# 25827            1  The source codes of 6 papers were not executab...
# 25828            3  [28] used biLSTM on table cell detection by en...
#
#              input_file_key majority_vote  majority_agreement  m1_label  \
# ...

# %%
joined_new_df['majority_vote'] = joined_new_df['majority_vote'].str.lower()

# %%
joined_new_df.to_csv(r"dataset/cc25k_dataset_m1.csv",index=False)

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report

# Load the CSV file
file_path = r"dataset/cc25k_dataset_m1.csv"  # Replace with your actual file path
df = pd.read_csv(file_path)

print("Model 1")
# Get the confusion matrix
y_true = df['majority_vote']  # Ground truth labels
y_pred = df['m1_label']       # Predicted labels

conf_matrix = confusion_matrix(y_true, y_pred, labels=y_true.unique())

# Display the confusion matrix
print("Confusion Matrix:")
print(conf_matrix)

# Optionally, display a classification report for more metrics
print("\nClassification Report:")
print(classification_report(y_true, y_pred))
# Out:
# Model 1
# Confusion Matrix:
# [[19988     9   451]
#  [ 5078     1    23]
#  [  180     0    99]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     negative       0.17      0.35      0.23       279
#      neutral       0.79      0.98      0.87     20448
#     positive       0.10      0.00      0.00      5102
#
#     accuracy                           0.78     25829
#    macro avg       0.35      0.44      0.37     25829
# weighted avg       0.65      0.78      0.70     25829

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Compute confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred, labels=y_true.unique())

# Create a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=y_true.unique(), yticklabels=y_true.unique())

# Add labels and title
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Compute confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred, labels=y_true.unique())

# Normalize by row (true label)
conf_matrix_normalized = conf_matrix.astype('float') / conf_matrix.sum(axis=1, keepdims=True)

# Create a heatmap with normalized values
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_normalized, annot=True, fmt='.2%', cmap='Blues', xticklabels=y_true.unique(), yticklabels=y_true.unique())

# Add labels and title
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Normalized Confusion Matrix (Percentages)')
plt.show()

# %%
conf_matrix_normalized
# Out:
# array([[9.77503912e-01, 4.40140845e-04, 2.20559468e-02],
#        [9.95295962e-01, 1.96001568e-04, 4.50803606e-03],
#        [6.45161290e-01, 0.00000000e+00, 3.54838710e-01]])

# %%
formatted_array = [[float(f"{val:.2f}") for val in row] for row in conf_matrix_normalized]
formatted_array
# Out:
# [[0.98, 0.0, 0.02], [1.0, 0.0, 0.0], [0.65, 0.0, 0.35]]

# %%
joined_new_df
# Out:
#        input_index                                      input_context  \
# 0                0  Instead of mixing the representations, G-Mixup...
# 1                3  For G-Mixup, we use the same hyper-parameters ...
# 2                6  G-Mixup performs mixup to the graphons of diff...
# 3                8  Our result generalizes that of [16] by allowin...
# 4                9  Note that for complexons of dimension 1, when ...
# ...            ...                                                ...
# 25824            2  A Jain [125] spatial associations + dynamic pr...
# 25825            3  A Jain [125] suggests training a deep network ...
# 25826            0  [39]12 2021 No name ICDAR PubTabNet ICDAR 2019...
# 25827            1  The source codes of 6 papers were not executab...
# 25828            3  [28] used biLSTM on table cell detection by en...
#
#              input_file_key majority_vote  majority_agreement  m1_label  \
# ...

# %% [markdown]
# # inferences model_02

# %%
# inferences model_02

predictions_df_m2 = joined_new_df.copy()
x_test_series_m2 = predictions_df_m2['input_context']
model_02_path = "sentiment_analysis/saved_5_models/model_02/"
loaded_model_02 = pipeline("text-classification", model = model_02_path, device=0)

predicted_m2 = loaded_model_02(list(x_test_series_m2),truncation=True)
df_predicted_m2 = pd.DataFrame(predicted_m2)
joined_new_df_m2 = predictions_df_m2.reset_index().join(df_predicted_m2, on='index', lsuffix='_')

model_2_label_mapping = {'LABEL_1':'neutral','LABEL_0':'negative','LABEL_2':'positive'}
joined_new_df_m2['label'] = joined_new_df_m2['label'].map(model_2_label_mapping)

joined_new_df_m2 = joined_new_df_m2.rename(columns={"label": "m2_label", "score": "m2_score"})
joined_new_df_m2 = joined_new_df_m2.drop(columns=['index'])
joined_new_df_m2

# LABEL_2 --> positive
# LABEL_0 --> negative
# LABEL_1 --> neutral
# Out:
#        input_index                                      input_context  \
# 0                0  Instead of mixing the representations, G-Mixup...
# 1                3  For G-Mixup, we use the same hyper-parameters ...
# 2                6  G-Mixup performs mixup to the graphons of diff...
# 3                8  Our result generalizes that of [16] by allowin...
# 4                9  Note that for complexons of dimension 1, when ...
# ...            ...                                                ...
# 25824            2  A Jain [125] spatial associations + dynamic pr...
# 25825            3  A Jain [125] suggests training a deep network ...
# 25826            0  [39]12 2021 No name ICDAR PubTabNet ICDAR 2019...
# 25827            1  The source codes of 6 papers were not executab...
# 25828            3  [28] used biLSTM on table cell detection by en...
#
#              input_file_key majority_vote  majority_agreement  m1_label  \
# ...

# %%
joined_new_df_m2.to_csv(r"dataset/cc25k_dataset_m1_m2.csv",index=False)

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report

# Load the CSV file
file_path = r"dataset/cc25k_dataset_m1_m2.csv"  # Replace with your actual file path
df = pd.read_csv(file_path)

print("Model 2")
# Get the confusion matrix
y_true = df['majority_vote']  # Ground truth labels
y_pred = df['m2_label']       # Predicted labels

conf_matrix = confusion_matrix(y_true, y_pred, labels=y_true.unique())

# Display the confusion matrix
print("Confusion Matrix:")
print(conf_matrix)

# Optionally, display a classification report for more metrics
print("\nClassification Report:")
print(classification_report(y_true, y_pred))
# Out:
# Model 2
# Confusion Matrix:
# [[16180  3903   365]
#  [ 4093   981    28]
#  [  221    24    34]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     negative       0.08      0.12      0.10       279
#      neutral       0.79      0.79      0.79     20448
#     positive       0.20      0.19      0.20      5102
#
#     accuracy                           0.67     25829
#    macro avg       0.36      0.37      0.36     25829
# weighted avg       0.67      0.67      0.67     25829

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Compute confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred, labels=y_true.unique())

# Create a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=y_true.unique(), yticklabels=y_true.unique())

# Add labels and title
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Compute confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred, labels=y_true.unique())

# Normalize by row (true label)
conf_matrix_normalized = conf_matrix.astype('float') / conf_matrix.sum(axis=1, keepdims=True)

# Create a heatmap with normalized values
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_normalized, annot=True, fmt='.2%', cmap='Blues', xticklabels=y_true.unique(), yticklabels=y_true.unique())

# Add labels and title
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Normalized Confusion Matrix (Percentages)')
plt.show()

# %%
formatted_array = [[float(f"{val:.2f}") for val in row] for row in conf_matrix_normalized]
formatted_array
# Out:
# [[0.79, 0.19, 0.02], [0.8, 0.19, 0.01], [0.79, 0.09, 0.12]]

# %% [markdown]
# # inferences model_03

# %%
# inferences model_03

predictions_df_m3 = joined_new_df_m2.copy() 
x_test_series_m3 = predictions_df_m3['input_context']
model_03_path = "sentiment_analysis/saved_5_models/model_03/"
loaded_model_03 = pipeline("text-classification", model = model_03_path, device=0)

predicted_m3 = loaded_model_03(list(x_test_series_m3),truncation=True)

df_predicted_m3 = pd.DataFrame(predicted_m3)
joined_new_df_m3 = predictions_df_m3.reset_index().join(df_predicted_m3, on='index', lsuffix='_')

model_3_label_mapping = {'NEU':'neutral','NEG':'negative','POS':'positive'}
joined_new_df_m3['label'] = joined_new_df_m3['label'].map(model_3_label_mapping)

joined_new_df_m3 = joined_new_df_m3.rename(columns={"label": "m3_label", "score": "m3_score"})
joined_new_df_m3 = joined_new_df_m3.drop(columns=['index'])
joined_new_df_m3
# Out:
#    input_index                                      input_context  \
# 0            0  Instead of mixing the representations, G-Mixup...
# 1            3  For G-Mixup, we use the same hyper-parameters ...
# 2            6  G-Mixup performs mixup to the graphons of diff...
# 3            8  Our result generalizes that of [16] by allowin...
# 4            9  Note that for complexons of dimension 1, when ...
#
#         input_file_key majority_vote  majority_agreement m1_label  m1_score  \
# 0  RS_001_MLRC_2022_01       neutral                   3  neutral  0.998696
# 1  RS_001_MLRC_2022_01      positive                   3  neutral  0.998802
# 2  RS_001_MLRC_2022_01       neutral                   2  neutral  0.998757
# 3  RS_001_MLRC_2022_01      positive                   2  neutral  0.998482
# 4  RS_001_MLRC_2022_01       neutral                   3  neutral  0.998866
#
#   m2_label  m2_score
# 0  neutral  0.997173
# 1  neutral  0.956996
# 2  neutral  0.997630
# ...

# %%
joined_new_df_m3.to_csv(r"dataset/cc25k_dataset_m1_m3.csv",index=False)

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report

# Load the CSV file
file_path = r"dataset/cc25k_dataset_m1_m3.csv"  # Replace with your actual file path
df = pd.read_csv(file_path)

print("Model 3")
# Get the confusion matrix
y_true = df['majority_vote']  # Ground truth labels
y_pred = df['m3_label']       # Predicted labels

conf_matrix = confusion_matrix(y_true, y_pred, labels=y_true.unique())

# Display the confusion matrix
print("Confusion Matrix:")
print(conf_matrix)

# Optionally, display a classification report for more metrics
print("\nClassification Report:")
print(classification_report(y_true, y_pred))
# Out:
# Model 3
# Confusion Matrix:
# [[16504  3264   680]
#  [ 4264   803    35]
#  [  139     4   136]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     negative       0.16      0.49      0.24       279
#      neutral       0.79      0.81      0.80     20448
#     positive       0.20      0.16      0.18      5102
#
#     accuracy                           0.68     25829
#    macro avg       0.38      0.48      0.40     25829
# weighted avg       0.67      0.68      0.67     25829

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Compute confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred, labels=y_true.unique())

# Create a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=y_true.unique(), yticklabels=y_true.unique())

# Add labels and title
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Compute confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred, labels=y_true.unique())

# Normalize by row (true label)
conf_matrix_normalized = conf_matrix.astype('float') / conf_matrix.sum(axis=1, keepdims=True)

# Create a heatmap with normalized values
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_normalized, annot=True, fmt='.2%', cmap='Blues', xticklabels=y_true.unique(), yticklabels=y_true.unique())

# Add labels and title
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Normalized Confusion Matrix (Percentages)')
plt.show()

# %%
formatted_array = [[float(f"{val:.2f}") for val in row] for row in conf_matrix_normalized]
formatted_array
# Out:
# [[0.81, 0.16, 0.03], [0.84, 0.16, 0.01], [0.5, 0.01, 0.49]]

# %% [markdown]
# # inferences model_04

# %%
# inferences model_04

predictions_df_m4 = joined_new_df_m3.copy() #[["text"]]
print(predictions_df_m4.head())
x_test_series_m4 = predictions_df_m4['input_context']
model_04_path = "sentiment_analysis/saved_5_models/model_04/"
loaded_model_04 = pipeline("text-classification", model = model_04_path, device=0)

predicted_m4 = loaded_model_04(list(x_test_series_m4),truncation=True)

df_predicted_m4 = pd.DataFrame(predicted_m4)
joined_new_df_m4 = predictions_df_m4.reset_index().join(df_predicted_m4, on='index', lsuffix='_')


joined_new_df_m4 = joined_new_df_m4.rename(columns={"label": "m4_label", "score": "m4_score"})
joined_new_df_m4 = joined_new_df_m4.drop(columns=['index'])
joined_new_df_m4
# Out:
#    input_index                                      input_context  \
# 0            0  Instead of mixing the representations, G-Mixup...
# 1            3  For G-Mixup, we use the same hyper-parameters ...
# 2            6  G-Mixup performs mixup to the graphons of diff...
# 3            8  Our result generalizes that of [16] by allowin...
# 4            9  Note that for complexons of dimension 1, when ...
#
#         input_file_key majority_vote  majority_agreement m1_label  m1_score  \
# 0  RS_001_MLRC_2022_01       neutral                   3  neutral  0.998696
# 1  RS_001_MLRC_2022_01      positive                   3  neutral  0.998802
# 2  RS_001_MLRC_2022_01       neutral                   2  neutral  0.998757
# 3  RS_001_MLRC_2022_01      positive                   2  neutral  0.998482
# 4  RS_001_MLRC_2022_01       neutral                   3  neutral  0.998866
#
#   m2_label  m2_score m3_label  m3_score
# 0  neutral  0.997173  neutral  0.896901
# ...

# %%
joined_new_df_m4.to_csv(r"dataset/cc25k_dataset_m1_m4.csv",index=False)

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report

# Load the CSV file
file_path = r"dataset/cc25k_dataset_m1_m4.csv"  # Replace with your actual file path
df = pd.read_csv(file_path)

print("Model 4")
# Get the confusion matrix
y_true = df['majority_vote']  # Ground truth labels
y_pred = df['m4_label']       # Predicted labels

conf_matrix = confusion_matrix(y_true, y_pred, labels=y_true.unique())

# Display the confusion matrix
print("Confusion Matrix:")
print(conf_matrix)

# Optionally, display a classification report for more metrics
print("\nClassification Report:")
print(classification_report(y_true, y_pred))
# Out:
# Model 4
# Confusion Matrix:
# [[15912  3260  1276]
#  [ 4296   714    92]
#  [  104     9   166]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     negative       0.11      0.59      0.18       279
#      neutral       0.78      0.78      0.78     20448
#     positive       0.18      0.14      0.16      5102
#
#     accuracy                           0.65     25829
#    macro avg       0.36      0.50      0.37     25829
# weighted avg       0.66      0.65      0.65     25829

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Compute confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred, labels=y_true.unique())

# Create a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=y_true.unique(), yticklabels=y_true.unique())

# Add labels and title
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Compute confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred, labels=y_true.unique())

# Normalize by row (true label)
conf_matrix_normalized = conf_matrix.astype('float') / conf_matrix.sum(axis=1, keepdims=True)

# Create a heatmap with normalized values
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_normalized, annot=True, fmt='.2%', cmap='Blues', xticklabels=y_true.unique(), yticklabels=y_true.unique())

# Add labels and title
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Normalized Confusion Matrix (Percentages)')
plt.show()

# %%
formatted_array = [[float(f"{val:.2f}") for val in row] for row in conf_matrix_normalized]
formatted_array
# Out:
# [[0.78, 0.16, 0.06], [0.84, 0.14, 0.02], [0.37, 0.03, 0.59]]

# %% [markdown]
# # inferences model_05

# %%
# inferences model_05

predictions_df_m5 = joined_new_df_m4.copy() #[["text"]]
x_test_series_m5 = predictions_df_m5['input_context']
model_05_path = "sentiment_analysis/saved_5_models/model_05/"
loaded_model_05 = pipeline("text-classification", model = model_05_path, device=0)

predicted_m5 = loaded_model_05(list(x_test_series_m5), truncation=True)

df_predicted_m5 = pd.DataFrame(predicted_m5)
joined_new_df_m5 = predictions_df_m5.reset_index().join(df_predicted_m5, on='index', lsuffix='_')

model_5_label_mapping = {'LABEL_1':'neutral','LABEL_0':'negative','LABEL_2':'positive'}
joined_new_df_m5['label'] = joined_new_df_m5['label'].map(model_5_label_mapping)

joined_new_df_m5 = joined_new_df_m5.rename(columns={"label": "m5_label", "score": "m5_score"})
joined_new_df_m5 = joined_new_df_m5.drop(columns=['index'])
joined_new_df_m5

# LABEL_2 --> positive
# LABEL_0 --> negative
# LABEL_1 --> neutral
# Out:
#        input_index                                      input_context  \
# 0                0  Instead of mixing the representations, G-Mixup...
# 1                3  For G-Mixup, we use the same hyper-parameters ...
# 2                6  G-Mixup performs mixup to the graphons of diff...
# 3                8  Our result generalizes that of [16] by allowin...
# 4                9  Note that for complexons of dimension 1, when ...
# ...            ...                                                ...
# 25824            2  A Jain [125] spatial associations + dynamic pr...
# 25825            3  A Jain [125] suggests training a deep network ...
# 25826            0  [39]12 2021 No name ICDAR PubTabNet ICDAR 2019...
# 25827            1  The source codes of 6 papers were not executab...
# 25828            3  [28] used biLSTM on table cell detection by en...
#
#              input_file_key majority_vote  majority_agreement  m1_label  \
# ...

# %%
joined_new_df_m5.to_csv(r"dataset/cc25k_dataset_m1_m5.csv",index=False)

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report

# Load the CSV file
file_path = r"dataset/cc25k_dataset_m1_m5.csv"  # Replace with your actual file path
df = pd.read_csv(file_path)

print("Model 5")
# Get the confusion matrix
y_true = df['majority_vote']  # Ground truth labels
y_pred = df['m5_label']       # Predicted labels

conf_matrix = confusion_matrix(y_true, y_pred, labels=y_true.unique())

# Display the confusion matrix
print("Confusion Matrix:")
print(conf_matrix)

# Optionally, display a classification report for more metrics
print("\nClassification Report:")
print(classification_report(y_true, y_pred))
# Out:
# Model 5
# Confusion Matrix:
# [[11461  3041  5946]
#  [ 3442   803   857]
#  [   26     7   246]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     negative       0.03      0.88      0.07       279
#      neutral       0.77      0.56      0.65     20448
#     positive       0.21      0.16      0.18      5102
#
#     accuracy                           0.48     25829
#    macro avg       0.34      0.53      0.30     25829
# weighted avg       0.65      0.48      0.55     25829

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Compute confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred, labels=y_true.unique())

# Create a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=y_true.unique(), yticklabels=y_true.unique())

# Add labels and title
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Compute confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred, labels=y_true.unique())

# Normalize by row (true label)
conf_matrix_normalized = conf_matrix.astype('float') / conf_matrix.sum(axis=1, keepdims=True)

# Create a heatmap with normalized values
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_normalized, annot=True, fmt='.2%', cmap='Blues', xticklabels=y_true.unique(), yticklabels=y_true.unique())

# Add labels and title
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Normalized Confusion Matrix (Percentages)')
plt.show()

# %%
formatted_array = [[float(f"{val:.2f}") for val in row] for row in conf_matrix_normalized]
formatted_array
# Out:
# [[0.56, 0.15, 0.29], [0.67, 0.16, 0.17], [0.09, 0.03, 0.88]]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Example confusion matrices for 5 models
model_reports = {
    "Sentiment Analysis Model 1": [[0.98, 0.00, 0.02], [1.00, 0.00, 0.00], [0.65, 0.00, 0.35]],
    "Sentiment Analysis Model 2": [[0.79, 0.19, 0.02], [0.80, 0.19, 0.01], [0.79, 0.09, 0.12]],
    "Sentiment Analysis Model 3": [[0.81, 0.16, 0.03], [0.84, 0.16, 0.01], [0.50, 0.01, 0.49]],
    "Sentiment Analysis Model 4": [[0.78, 0.16, 0.06], [0.84, 0.14, 0.02], [0.37, 0.03, 0.59]],
    "Sentiment Analysis Model 5": [[0.56, 0.15, 0.29], [0.67, 0.16, 0.17], [0.09, 0.03, 0.88]],
}

# Classes for the confusion matrix
classes = ["negative", "neutral", "positive"]

# Create subplots
fig, axes = plt.subplots(1, 5, figsize=(25, 5), sharey=True)  # 1 row, 5 columns

# Plot each confusion matrix
count =0
for ax, (model_name, conf_matrix) in zip(axes, model_reports.items()):
    sns.heatmap(conf_matrix, annot=True, fmt=".2f", cmap="Blues", xticklabels=classes, yticklabels=classes, ax=ax,annot_kws={"fontsize": 22}) #Blues bone
    ax.set_title(model_name)
    ax.set_xlabel("Predicted")
    if count ==0:
        ax.set_ylabel("Majority Voted Label (True)")
    count =+1

# Adjust layout for better visualization
plt.tight_layout()

plt.savefig(r'plots/cf_matrix.pdf')
plt.show()

# %% [markdown]
# # word cloud

# %%
import pandas as pd
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

file_path = r"dataset/cc25k_dataset_m1_m5.csv"  # Replace with your actual file path
df = pd.read_csv(file_path)

# Initialize the figure and subplots
fig, axes = plt.subplots(1, 3, figsize=(15, 5))  # 1 row, 3 columns

# Categories for which to generate word clouds
categories = ["neutral", "positive", "negative"]

# Define a custom set of words to exclude (you can expand this list as needed)
custom_stopwords = set(STOPWORDS).union({"et al", "et", "al", "and", "a"})  # Adding some extra words

# Generate word clouds per category and plot them in subplots
for ax, category in zip(axes, categories):
    category_texts = " ".join(df[df["majority_vote"] == category]["input_context"])
    wordcloud = WordCloud(width=800, height=400, background_color="white", stopwords=custom_stopwords).generate(category_texts)
    
    # Display the wordcloud
    ax.imshow(wordcloud, interpolation="bilinear")
    ax.axis("off")
    ax.set_title(f"Word Cloud for {category.capitalize()} Category")

# Adjust layout
plt.tight_layout(rect=[0, 0, 1, 1])
plt.savefig(r'plots/word_cloud.pdf')
plt.show()

# %% [markdown]
# # word and sentence counts distribution for each label category (using NLTK)

# %%
# Group by the category (e.g., majority_vote) and calculate the mean for each category
category_avg = df.groupby('majority_vote')[['word_count', 'sentence_count']].mean()

# Display the average word and sentence count per category
print(category_avg)
# Out:
#                word_count  sentence_count
# majority_vote
# negative        35.956989        1.186380
# neutral         36.028022        1.293867
# positive        36.546844        1.331635

# %%
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from nltk.tokenize import word_tokenize, sent_tokenize

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import nltk

# Load your dataset (replace with your actual file path)
file_path = r"dataset/cc25k_dataset_m1_m5.csv"  # Replace with your actual file path
df = pd.read_csv(file_path)

# Function to calculate word count using nltk.word_tokenize
def word_count(text):
    words = word_tokenize(text)  # Tokenize text into words
    return len(words)

# Function to calculate sentence count using nltk.sent_tokenize
def sentence_count(text):
    sentences = sent_tokenize(text)  # Tokenize text into sentences
    return len(sentences)

# Add word count and sentence count for each context
df['word_count'] = df['input_context'].apply(word_count)
df['sentence_count'] = df['input_context'].apply(sentence_count)

# Create bins for word count distribution
word_bins = range(0, 81, 4)  # Bins from 0 to 80 with a step of 4

# Create a figure for the main plot
fig, ax = plt.subplots(figsize=(8, 6))

# Categories for visualization
categories = ["neutral", "positive", "negative"]
colors = ['#86bbd8', '#6bbf59', '#a4243b']  # Colors for each category skyblue salmon a4133c b5e2fa lightgreen 69b578 a9e5bb
 
# Plot the distribution of word counts per context for each category with fixed bin positions
for category, color in zip(categories, colors):
    category_df = df[df["majority_vote"] == category]
    sns.histplot(category_df['word_count'], bins=word_bins, color=color, label=category, kde=False, kde_kws={'bw_adjust': 0.5},  ax=ax, alpha=0.8, edgecolor='#343a40')

# Set the x-axis limit to stop at word count 80
ax.set_xlim(0, 80)

# Add titles, labels, and legend
ax.set_xlabel("Word Count per Context")
ax.set_ylabel("Frequency (Log Scale)")
ax.legend(title="Categories", loc='upper left')

# Create inset axes for sentence count distribution
axins = inset_axes(ax, width="30%", height="30%", loc='upper right',
                   bbox_to_anchor=(-0.05, -0.1, 1.0, 1.0), bbox_transform=ax.transAxes)

# Plot the sentence count distribution as a bar plot in the inset
for category, color in zip(categories, colors):
    category_df = df[df["majority_vote"] == category]
    sns.histplot(category_df['sentence_count'], bins=range(0, 9), color=color, label=category, discrete=True, ax=axins, alpha=1.0, edgecolor='#343a40')  # Set alpha=1 to remove transparency

# Set the x-axis limit for the inset plot to stop at sentence count 8
axins.set_xlim(0, 9)
axins.set_xticks(range(0, 10))  # Ensure only integer ticks from 0 to 8 are shown

# Set the y-axis of the inset plot to log scale
axins.set_yscale('log')

# Add titles and labels to the inset plot
axins.set_title("Sentence Count Distribution")
axins.set_xlabel("Sentence Count")
axins.set_ylabel("Frequency (Log Scale)")

# Show the plot
plt.tight_layout()
plt.savefig(r'plots/word_count_distribution_with_inset_log.pdf')  # Save the plot as a PDF (optional)
plt.show()

# Calculate average word count per context
avg_word_count = df['word_count'].mean()

# Calculate average sentence count per context
avg_sentence_count = df['sentence_count'].mean()

# Display the results
print(f"Average word count per context: {avg_word_count:.2f}")
print(f"Average sentence count per context: {avg_sentence_count:.2f}")
# Out:
# /tmp/ipykernel_3505961/2551823130.py:77: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# Average word count per context: 36.13
# Average sentence count per context: 1.30
